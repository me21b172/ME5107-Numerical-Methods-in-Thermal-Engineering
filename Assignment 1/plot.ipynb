# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X = [32, 128, 521, 1024]
Y = [1024, 16384, 271441, 1048576]

# %%
plt.plot(X, Y, 'ro-')
plt.xlabel('N')
plt.ylabel('1/$\Sigma(x_i^2)$')
plt.title('1/$\Sigma(x_i^2)$ vs N')
plt.savefig('plot.png')
